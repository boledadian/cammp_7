# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras as ks
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.gaussian_process import GaussianProcessRegressor as gpr 
from sklearn.gaussian_process.kernels import ConstantKernel,DotProduct, RBF, RationalQuadratic, ExpSineSquared, Matern, Exponentiation

# %%
df = pd.read_excel('./Gibbs energy inference.xlsx')
df_Fe_C = pd.read_excel('./Fe-C system.xlsx')
df_Fe_Cr = pd.read_excel('./Fe-Cr system.xlsx')
df_Fe_C_Cr = pd.read_excel('./Fe-C-Cr system.xlsx')

# %%
df_Fe_C_1=df_Fe_C.reindex(columns=['Wt-% Cr','Wt-% C', 'T/K', 'Gibbs_energy/J/mol'], fill_value=0)

# %%
df_Fe_Cr_1=df_Fe_Cr.reindex(columns=['Wt-% Cr','Wt-% C', 'T/K', 'Gibbs_energy/J/mol'], fill_value=0)

# %%
df=pd.concat([df_Fe_C_1,df_Fe_Cr_1,df_Fe_C_Cr]).reset_index(drop=True)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaler = pd.DataFrame(scaler.fit_transform(df))
# Out:
# e:\miniconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
Train = df_scaler.loc[:95].rename(columns={0:'Wt-% Cr',1:'Wt-% C',2:'T/K',3:'Gibbs_energy/J/mol'})

# %%
Test = df_scaler.loc[96:].reset_index(drop=True).rename(columns={0:'Wt-% Cr',1:'Wt-% C',2:'T/K',3:'Gibbs_energy/J/mol'})

# %%
Train.plot(kind = 'kde', figsize = (5, 5))

# %%
X_train=Train[['Wt-% Cr','Wt-% C', 'T/K']]
y_train=Train['Gibbs_energy/J/mol']
X_test=Test[['Wt-% Cr','Wt-% C', 'T/K']]
y_test=Test['Gibbs_energy/J/mol']

# %%
Gaussian= gpr(alpha = 0.0001,n_restarts_optimizer=5,normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=42)
#kernel=k,alpha = 0.0001,n_restarts_optimizer=5,normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=42)
Gaussian.fit(X_train,y_train)
# Out:
# GaussianProcessRegressor(alpha=0.0001, copy_X_train=True, kernel=None,
#              n_restarts_optimizer=5, normalize_y='True',
#              optimizer='fmin_l_bfgs_b', random_state=42)

# %%
y_prediction=Gaussian.predict(Test[['Wt-% Cr','Wt-% C', 'T/K']])

# %%
y_prediction
# Out:
# array([0.59108081, 0.46131501, 0.33230424, 0.33024273, 0.58891151,
#        0.64056851, 0.61756255, 0.50143409, 0.80823963, 0.31113611,
#        0.30839167, 0.48582296, 0.74799793, 0.56318298, 0.6122341 ,
#        0.46237685])

# %%
np.array(Test['Gibbs_energy/J/mol'])
# Out:
# array([0.58214092, 0.45530222, 0.32987302, 0.32491439, 0.58019074,
#        0.63402247, 0.58600584, 0.49589399, 0.78748743, 0.2956694 ,
#        0.30661721, 0.43103897, 0.66929823, 0.39791365, 0.50687877,
#        0.42486956])

# %%
def Mean_absolute_percentage_error(ture_value, prediction_value):
    return np.mean(np.abs((prediction_value- ture_value))/ture_value)*100

# %%
Mean_absolute_percentage_error(Test['Gibbs_energy/J/mol'].values,y_prediction)
# Out:
# 7.3957131867002035

# %%
Gaussian.score(Test[['Wt-% Cr','Wt-% C', 'T/K']],Test['Gibbs_energy/J/mol'])
# Out:
# 0.8350965802073895

# %%
from pandas.core.frame import DataFrame
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from sklearn import linear_model
from sklearn.ensemble import BaggingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.kernel_ridge import KernelRidge
import xgboost as xgb
import lightgbm as lgb

from sklearn.naive_bayes import MultinomialNB

# %%
# Modeling step Test differents algorithms 
random_state = 42
Regressors = []
Regressors.append(RandomForestRegressor(random_state=random_state))
Regressors.append(ExtraTreesRegressor(random_state=random_state))
Regressors.append(GradientBoostingRegressor(random_state=random_state))
Regressors.append(linear_model.BayesianRidge())
Regressors.append(BaggingRegressor(random_state=random_state))
Regressors.append(linear_model.ARDRegression())
Regressors.append(MLPRegressor(activation='relu', solver='adam', alpha=0.0001, max_iter=10000,random_state=random_state))
Regressors.append(DummyRegressor())
Regressors.append(DecisionTreeRegressor(random_state=random_state))
Regressors.append(KNeighborsRegressor(weights='uniform'))
Regressors.append(KNeighborsRegressor(weights='distance'))
Regressors.append(SGDRegressor(random_state=random_state))
Regressors.append(SVR(kernel='linear'))
Regressors.append(SVR(kernel='poly'))
Regressors.append(SVR(kernel='rbf',C=1))
Regressors.append(LinearRegression())
Regressors.append(RidgeCV())
Regressors.append(LassoCV())
Regressors.append(ElasticNetCV())
Regressors.append(KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5))
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)
Regressors.append(model_xgb)
Regressors.append(model_lgb)
Regressors.append(gpr(kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0))
Regressors.append(gpr(kernel=1**2 * DotProduct(sigma_0=1),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0))
Regressors.append(gpr(kernel=1**2 * RBF(length_scale=1),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0))
Regressors.append(gpr(kernel=1**2 * RationalQuadratic(alpha=1, length_scale=1),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0))
Regressors.append(gpr(kernel=1**2 * Matern(length_scale=1, nu=1.5),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0))

# %%
string= ['RandomForest','ExtraTrees','GradientBoosting', 'BayesianRidge','Bagging','ARD','MultipleLayerPerceptron','Dummy',
        'DecisionTree','KNeighbor(Arithmetic mean)','KNeighbor(weighed mean)','Linear','SGD','poly_SVR','rbf_SVR',
         'linear_SVR','RidgeCV','LassoCV','ElasticNetCV','KernelRidge','XGBoost','LightGBM',
         'Gaussian_ExpSineSquared','Gaussian_DotProduct','Gaussian_RBF','Gaussian_RationalQuadratic','Gaussian_Matern']
data_total=pd.DataFrame()
data_R2=pd.DataFrame()
data_MAPE=pd.DataFrame()
model_list = [RandomForestRegressor(),ExtraTreesRegressor(),GradientBoostingRegressor(), 
              linear_model.BayesianRidge(),BaggingRegressor(),linear_model.ARDRegression(),
             MLPRegressor(activation='relu', solver='adam', alpha=0.0001, max_iter=10000),
             DummyRegressor(),DecisionTreeRegressor(),
             KNeighborsRegressor(weights='uniform'),KNeighborsRegressor(weights='distance'), 
             SGDRegressor(),SVR(kernel='linear'),SVR(kernel='poly'),SVR(kernel='rbf',C=1),
             LinearRegression(),RidgeCV(),LassoCV(),ElasticNetCV(),
             KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5),
             model_xgb,model_lgb,
             gpr(kernel=1**2 * ExpSineSquared(length_scale=1, periodicity=1),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0),
             gpr(kernel=1**2 * DotProduct(sigma_0=1),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0),
             gpr(kernel=1**2 * RBF(length_scale=1),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0),
             gpr(kernel=1**2 * RationalQuadratic(alpha=1, length_scale=1),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0),
             gpr(kernel=1**2 * Matern(length_scale=1, nu=1.5),n_restarts_optimizer=5,
                      normalize_y="True",optimizer='fmin_l_bfgs_b',random_state=0)]
for index, model in enumerate (model_list):
    R2=[]
    MAPE=[]
    MSE=[]
    MAE=[]
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    R2.append(model.score(X_test, y_test))
    MAPE.append(my_custom_score_func(y_test, y_predict))
    MSE.append(mean_squared_error(y_test, y_predict))
    MAE.append(mean_absolute_error(y_test, y_predict))
    a=np.vstack((np.array(R2),np.array(MAPE),np.array(MSE),np.array(MAE)))#所有的array并列起来
    data1 = pd.DataFrame(a, index=['%s R2'% string[index],'%s MAPE'% string[index], '%s MSE' %string[index],
                                   '%s  MAE'% string[index]], 
                         columns=['Gibbs_energy/J/mol'])  
    data2 = pd.DataFrame(np.matrix(R2), index=['%s R2'% string[index]],
                                   columns=['Gibbs_energy/J/mol']) 
    data3= pd.DataFrame(np.matrix(MAPE), index=['%s MAPE'% string[index]],
                                   columns=['Gibbs_energy/J/mol'])
    data_total=pd.concat([data_total,data1])#生成纵轴上的并集，索引会自动生成新的一
    data_R2=pd.concat([data_R2,data2])
    data_MAPE=pd.concat([data_MAPE,data3])

pd.set_option('display.max_columns', None)#显示pandas完整数据
pd.set_option('display.max_rows', None)
data_total
# Out:
# e:\miniconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\miniconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# e:\miniconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDRegressor in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# ...

# %%
data_R2
# Out:
#                                Gibbs_energy/J/mol
# RandomForest R2                          0.948103
# ExtraTrees R2                            0.939524
# GradientBoosting R2                      0.953978
# BayesianRidge R2                         0.919857
# Bagging R2                               0.932522
# ARD R2                                   0.919248
# MultipleLayerPerceptron R2               0.634397
# Dummy R2                                -0.145384
# DecisionTree R2                          0.875347
# KNeighbor(Arithmetic mean) R2            0.900914
# KNeighbor(weighed mean) R2               0.906561
# Linear R2                               -0.385687
# SGD R2                                   0.831080
# poly_SVR R2                              0.551999
# rbf_SVR R2                               0.888821
# linear_SVR R2                            0.919448
# RidgeCV R2                               0.985863
# LassoCV R2                               0.950450
# ...

# %%
data_R2.plot.bar(figsize=(20, 10))
plt.ylim(-0.1,1)
# Out:
# (-0.1, 1)

# %%
data_MAPE
# Out:
#                                  Gibbs_energy/J/mol
# RandomForest MAPE                          6.658226
# ExtraTrees MAPE                            6.631960
# GradientBoosting MAPE                      5.793462
# BayesianRidge MAPE                         6.375570
# Bagging MAPE                               7.420108
# ARD MAPE                                   6.401457
# MultipleLayerPerceptron MAPE              15.175779
# Dummy MAPE                                31.252354
# DecisionTree MAPE                          9.537101
# KNeighbor(Arithmetic mean) MAPE            8.517252
# KNeighbor(weighed mean) MAPE               8.125557
# Linear MAPE                               28.336628
# SGD MAPE                                   8.988245
# poly_SVR MAPE                             18.268248
# rbf_SVR MAPE                               7.326784
# linear_SVR MAPE                            6.388971
# RidgeCV MAPE                               3.283325
# ...

# %%
#pd.set_option('mpl_style','default')
data_MAPE['Gibbs_energy/J/mol'].plot(kind='barh',figsize=(10, 10))

# %%
data_MAPE.plot.bar(figsize=(20, 7))

# %%
data_MAPE.plot(kind='barh',stacked=True,figsize=(15, 10))
plt.xlabel(u"MAPE Value")# plots an axis lable
plt.ylabel(u"Algorithm") 
plt.title(u"MAPE of Different Algorithm")
plt.savefig('./ MAPE of Different Algorithm.png',format='png')
