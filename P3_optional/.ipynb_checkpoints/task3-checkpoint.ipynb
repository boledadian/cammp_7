# %%
import pandas as pd
data = pd.read_csv("E_Vo_withDatafromPeriodicTable.csv")
df= pd.DataFrame(data)

# %%
df.keys()
# Out:
# Index(['Chemical formula', 'A', 'B', 'In literature', 'Valence A', 'Valence B',
#        'Radius A [ang]', 'Radius B [ang]', 'Lowest distortion',
#        'Formation energy [eV/atom]', 'Stability [eV/atom]',
#        'Magnetic moment [mu_B]', 'Volume per atom [A^3/atom]', 'Band gap [eV]',
#        'a [ang]', 'b [ang]', 'c [ang]', 'alpha [deg]', 'beta [deg]',
#        'gamma [deg]', 'A-AtomicNumber', 'A-AtomicMass', 'A-NumberofNeutrons',
#        'A-NumberofProtons', 'A-NumberofElectrons', 'A-Period', 'A-Group',
#        'A-AtomicRadius', 'A-Electronegativity', 'A-FirstIonization',
#        'A-Density', 'A-MeltingPoint', 'A-BoilingPoint', 'A-NumberOfIsotopes',
#        'A-SpecificHeat', 'A-NumberofShells', 'B-AtomicNumber', 'B-AtomicMass',
#        'B-NumberofNeutrons', 'B-NumberofProtons', 'B-NumberofElectrons',
#        'B-Period', 'B-Group', 'B-Electronegativity', 'B-FirstIonization',
#        'B-Density', 'B-MeltingPoint', 'B-BoilingPoint', 'B-NumberOfIsotopes',
#        'B-SpecificHeat', 'B-NumberofShells', 'Vacancy energy [eV/O atom]'],
#       dtype='object')

# %%
df_temp1= [df['B'] == 'Fe']
df_temp2= [df['B'] == 'Co']

# %%
name = ['Fe','Co']
df_temp = df[df['B'].isin(name)]

# %%
df_temp.head()
# Out:
#     Chemical formula   A   B  In literature          Valence A  \
# 876           AcCoO3  Ac  Co          False  element not in BV
# 877           AgCoO3  Ag  Co          False       not balanced
# 878           AlCoO3  Al  Co          False                  3
# 879           AsCoO3  As  Co          False                  3
# 880           AuCoO3  Au  Co          False  element not in BV
#
#              Valence B  Radius A [ang]  Radius B [ang] Lowest distortion  \
# 876  element not in BV            1.12            0.63      rhombohedral
# 877       not balanced            1.28            0.63      orthorhombic
# 878                  3            0.54            0.61             cubic
# 879                  3            0.58            0.61             cubic
# 880  element not in BV            0.93            0.63             cubic
#
#     Formation energy [eV/atom]  ... B-Group B-Electronegativity  \
# 876                     -2.426  ...     9.0                1.88
# 877                     -0.481  ...     9.0                1.88
# 878                     -0.957  ...     9.0                1.88
# 879                     -0.584  ...     9.0                1.88
# 880                     -0.071  ...     9.0                1.88
#
#     B-FirstIonization B-Density B-MeltingPoint B-BoilingPoint  \
# 876             7.881      8.86        1768.15           3200
# 877             7.881      8.86        1768.15           3200
# 878             7.881      8.86        1768.15           3200
# 879             7.881      8.86        1768.15           3200
# 880             7.881      8.86        1768.15           3200
#
#     B-NumberOfIsotopes B-SpecificHeat B-NumberofShells  \
# 876                 14          0.421                4
# 877                 14          0.421                4
# 878                 14          0.421                4
# 879                 14          0.421                4
# 880                 14          0.421                4
#
#     Vacancy energy [eV/O atom]
# 876                       3.33
# 877                          -
# 878                     -1.991
# 879                      0.089
# 880                     -2.143
#
# [5 rows x 52 columns]

# %%
df_temp = df_temp[['Radius A [ang]', 'A-Density','A-AtomicNumber','A-SpecificHeat','B-AtomicMass','Vacancy energy [eV/O atom]']]

# %%
df_temp
# Out:
#       Radius A [ang]  A-Density  A-AtomicNumber  A-SpecificHeat  B-AtomicMass  \
# 876             1.12     10.100              89           0.120        58.933
# 877             1.28     10.500              47           0.235        58.933
# 878             0.54      2.700              13           0.897        58.933
# 879             0.58      5.780              33           0.329        58.933
# 880             0.93     19.300              79           0.129        58.933
# 881             0.27      2.340               5           1.026        58.933
# 882             1.61      3.590              56           0.204        58.933
# 883             0.45      1.850               4           1.825        58.933
# 884             1.38      9.810              83           0.122        58.933
# 885             1.34      1.540              20           0.647        58.933
# 886             1.31      8.690              48           0.232        58.933
# 887             1.34      6.770              58           0.192        58.933
# 888             0.61      8.860              27           0.421        58.933
# 889             0.80      7.150              24           0.449        58.933
# 890             1.88      1.870              55           0.242        58.933
# 891             0.73      8.960              29           0.385        58.933
# 892             1.08      8.550              66           0.170        58.933
# 893             1.06      9.070              68           0.168        58.933
# 894             1.48      5.240              63           0.182        58.933
# 895             0.92      7.870              26           0.449        58.933
# 896             0.62      5.910              31           0.371        58.933
# 897             1.11      7.900              64           0.236        58.933
# 898             0.73      5.320              32           0.320        58.933
# 899             0.83     13.300              72           0.144        58.933
# 900             1.14     13.500              80           0.140        58.933
# 901             1.12      8.800              67           0.165        58.933
# 902             0.92      7.310              49           0.233        58.933
# 903             0.68     22.600              77           0.131        58.933
# 904             1.64      0.862              19           0.757        58.933
# 905             1.36      6.150              57           0.195        58.933
# ...              ...        ...             ...             ...           ...
# 1430            0.76     12.000              46           0.244        55.845
# 1431            1.14      7.260              61             NaN        55.845
# 1432            1.18      6.770              59           0.193        55.845
# 1433            0.67     21.500              78           0.133        55.845
# 1434            0.96     19.800              94             NaN        55.845
# 1435            1.72      1.530              37           0.363        55.845
# 1436            0.58     21.000              75           0.137        55.845
# 1437            0.67     12.400              45           0.243        55.845
# 1438            0.68     12.400              44           0.238        55.845
# 1439            0.76      6.690              51           0.207        55.845
# 1440            0.87      2.990              21           0.568        55.845
# 1441            0.40      2.330              14           0.705        55.845
# 1442            1.24      7.520              62           0.197        55.845
# 1443            0.81      7.290              50           0.228        55.845
# 1444            1.44      2.640              38           0.301        55.845
# 1445            0.74     16.700              73           0.140        55.845
# 1446            1.10      8.230              65           0.182        55.845
# 1447            0.60     11.500              43             NaN        55.845
# 1448            0.97      6.230              52           0.202        55.845
# 1449            1.21     11.700              90           0.113        55.845
# 1450            0.86      4.540              22           0.523        55.845
# 1451            0.98     11.900              81           0.129        55.845
# 1452            1.05      9.320              69           0.160        55.845
# 1453            1.03     19.000              92           0.116        55.845
# 1454            0.79      6.110              23           0.489        55.845
# 1455            0.66     19.300              74           0.132        55.845
# 1456            1.08      4.470              39           0.298        55.845
# 1457            1.04      6.970              70           0.155        55.845
# 1458            0.90      7.130              30           0.388        55.845
# 1459            0.89      6.510              40           0.278        55.845
#
#      Vacancy energy [eV/O atom]
# 876                        3.33
# 877                           -
# 878                      -1.991
# 879                       0.089
# 880                      -2.143
# 881                      -2.534
# 882                       0.663
# 883                      -2.203
# 884                       2.897
# 885                        0.72
# 886                      -0.458
# 887                        3.21
# 888                        -2.8
# 889                      -1.758
# 890                           -
# 891                      -1.005
# 892                           -
# 893                       2.225
# 894                        1.59
# 895                      -1.547
# 896                     -11.419
# 897                           -
# 898                       0.905
# 899                         0.8
# 900                      -1.207
# 901                        2.32
# 902                       0.504
# 903                      -5.721
# 904                      -2.955
# 905                       2.964
# ...                         ...
# 1430                     -1.858
# 1431                        3.7
# 1432                      3.968
# 1433                     -3.036
# 1434                          -
# 1435                     -1.062
# 1436                     -4.592
# 1437                     -2.494
# 1438                     -2.602
# 1439                      1.172
# 1440                      1.505
# 1441                     -1.814
# 1442                      3.624
# 1443                      0.792
# 1444                      1.378
# 1445                     -4.452
# 1446                      3.264
# 1447                      -1.97
# 1448                     -0.992
# 1449                      3.482
# 1450                     -0.463
# 1451                     -0.727
# 1452                      2.865
# 1453                      2.177
# 1454                          -
# 1455                     -2.876
# 1456                       3.19
# 1457                      1.336
# 1458                      -0.75
# 1459                        1.3
#
# [146 rows x 6 columns]

# %%
# from sklearn.preprocessing import LabelEncoder
# lt = LabelEncoder()
# df_temp['Lowest distortion'] = lt.fit_transform(df_temp['Lowest distortion'])
# df_temp['A'] = lt.fit_transform(df_temp['A'])

# %%
# df_temp = df_temp.drop(['Chemical formula','alpha [deg]','beta [deg]','gamma [deg]','In literature'], axis = 1)
# df_temp.head()

# %%
 import numpy as np
# df_temp['Valence A'].replace(r'\s+', np.nan, regex=True, inplace=True)
# df_temp['Valence B'].replace(r'\s+', np.nan, regex=True, inplace=True)
#weirdString = '-'#df_temp['Vacancy energy [eV/O atom]'][0:]
#df_temp['Vacancy energy [eV/O atom]'].replace(weirdString, np.nan, inplace=True)
df_temp = df_temp.replace(to_replace='-',value=np.nan)
display(df_temp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 876 to 1459
# Data columns (total 6 columns):
# Radius A [ang]                146 non-null float64
# A-Density                     146 non-null float64
# A-AtomicNumber                146 non-null int64
# A-SpecificHeat                136 non-null float64
# B-AtomicMass                  146 non-null float64
# Vacancy energy [eV/O atom]    124 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 8.0+ KB
# None

# %%
# type(df_temp['Vacancy energy [eV/O atom]'][85])
# df_temp['Vacancy energy [eV/O atom]'][85]
#weirdString == df_temp['Vacancy energy [eV/O atom]'][85]

# %%
df_temp = df_temp.dropna()

# %%
df_temp.keys()
# Out:
# Index(['Radius A [ang]', 'A-Density', 'A-AtomicNumber', 'A-SpecificHeat',
#        'B-AtomicMass', 'Vacancy energy [eV/O atom]'],
#       dtype='object')

# %%
#df_temp = df_temp.drop(['B', 'A'], axis=1)
df_temp = df_temp.astype(float)

# %%
df_temp.keys()
# Out:
# Index(['Radius A [ang]', 'A-Density', 'A-AtomicNumber', 'A-SpecificHeat',
#        'B-AtomicMass', 'Vacancy energy [eV/O atom]'],
#       dtype='object')

# %%
#df_temp = df_temp.drop(['B', 'A'], axis=1)
#df_temp = df_temp.astype(float)
#df_temp = df_temp[['Radius A [ang]','Formation energy [eV/atom]','Stability [eV/atom]',
#                   'Volume per atom [A^3/atom]','Magnetic moment [mu_B]','a [ang]',
#                   'Vacancy energy [eV/O atom]']]
display(df_temp.head())
display(df_temp.describe())
# Out:
#      Radius A [ang]  A-Density  A-AtomicNumber  A-SpecificHeat  B-AtomicMass  \
# 876            1.12      10.10            89.0           0.120        58.933
# 878            0.54       2.70            13.0           0.897        58.933
# 879            0.58       5.78            33.0           0.329        58.933
# 880            0.93      19.30            79.0           0.129        58.933
# 881            0.27       2.34             5.0           1.026        58.933
#
#      Vacancy energy [eV/O atom]
# 876                       3.330
# 878                      -1.991
# 879                       0.089
# 880                      -2.143
# 881                      -2.534
#        Radius A [ang]   A-Density  A-AtomicNumber  A-SpecificHeat  \
# count      118.000000  118.000000      118.000000      118.000000
# mean         0.958983    8.575542       48.644068        0.396703
# std          0.327099    5.598360       24.603358        0.521778
# min          0.270000    0.534000        3.000000        0.113000
# 25%          0.697500    5.260000       27.500000        0.154250
# 50%          0.920000    7.480000       48.500000        0.232500
# 75%          1.170000   11.025000       70.750000        0.412750
# max          1.720000   22.600000       92.000000        3.582000
#
#        B-AtomicMass  Vacancy energy [eV/O atom]
# count    118.000000                  118.000000
# mean      57.336661                   -0.063907
# std        1.549693                    2.549775
# min       55.845000                  -11.419000
# 25%       55.845000                   -1.636250
# 50%       55.845000                    0.079500
# 75%       58.933000                    1.834250
# max       58.933000                    4.135000

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X = df_temp.values[:, 0:-1]
# X = df_temp.values[]
Y = df_temp.values[:,-1]
print(Y)
# Out:
# [  3.33   -1.991   0.089  -2.143  -2.534   0.663  -2.203   2.897   0.72
#   -0.458   3.21   -2.8    -1.758  -1.005   2.225   1.59   -1.547 -11.419
#    0.905   0.8    -1.207   2.32    0.504  -5.721  -2.955   2.964   0.263
#    1.89   -0.239  -0.95    0.679   0.373   3.124  -2.69    0.756  -0.712
#   -4.105   0.199  -5.095  -0.711  -2.148   2.075   1.089  -1.423   2.931
#    0.687  -0.411   2.511   1.913   3.147   0.232  -0.542   2.096  -1.853
#   -2.7    -1.336   1.235   4.135  -2.445  -0.724  -1.534  -3.619   1.185
#   -1.666   2.587   1.132   0.208   4.094  -0.624  -1.245  -1.512   3.193
#    1.667  -1.446  -2.251   3.384   0.461  -0.324   3.094  -4.804  -0.61
#    4.037  -0.831   2.726   0.07    0.308  -2.265  -0.436  -0.263   3.83
#   -4.938   0.789  -1.858   3.968  -3.036  -1.062  -4.592  -2.494  -2.602
#    1.172   1.505  -1.814   3.624   0.792   1.378  -4.452   3.264  -0.992
#    3.482  -0.463  -0.727   2.865   2.177  -2.876   3.19    1.336  -0.75
#    1.3  ]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
# model = LogisticRegression()
# rfe = RFE(model, 4)
# fit = rfe.fit(X, Y)

# %%
# print("Num Features: %s" % (fit.n_features_))
# print("Selected Features: %s" % (fit.support_))
# print("Feature Ranking: %s" % (fit.ranking_))

# %%
# import seaborn as sns
# #sns.p(df_temp[0:5])
# #pd.plotting.scatter_matrix(df_temp[11:14])
# sns.pairplot(df_temp.iloc[:,11:13], hue = df_temp.iloc[:, 14])

# %%
# fit.ranking_

# %%
# ind = np.where(fit.ranking_ == 1)
# idx = [item for item in ind[0]]

# %%
import seaborn as sns
display(sns.pairplot(df_temp))
import matplotlib.pyplot as plt
plt.savefig("pairplot_features_selected.png")

# %%
display(X.shape)
display(Y.shape)
# Out:
# (118, 5)
# (118,)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
scaler = StandardScaler()
#scaler  = MinMaxScaler()
X = scaler.fit_transform(X)
#Y = scaler.fit_transform(Y.reshape(-1,1))

# %%
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
clf = SVR(gamma=0.1, kernel='rbf',C = 5)
clf.fit(X_train, Y_train) 
print(len(X_train), len(X_test))
# Out:
# 94 24

# %%
Y_pred = clf.predict(X_test)
from sklearn.metrics import mean_squared_error
print(mean_squared_error(Y_pred,Y_test))
plt.scatter(X_test[:,0], Y_test)
plt.scatter(X_test[:,0], Y_pred)
# Out:
# 0.7115942897315297

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(X_train, Y_train) 
Y_pred = knn.predict(X_test)
print(mean_squared_error(Y_pred,Y_test))
plt.scatter(X_test[:, 0], Y_test)
plt.scatter(X_test[:, 0], Y_pred)
# Out:
# 2.4371076157407408

# %%
Y_train
# Out:
# array([  2.931,  -1.758,   1.59 ,  -1.512,  -0.992,  -2.955,   0.208,
#          0.504,  -4.105,  -1.336,   4.037,   0.679,   1.185,   1.667,
#         -0.458,  -2.69 ,  -4.452,  -0.624,  -0.239,   2.511,   0.07 ,
#          0.663,  -0.324,   4.094,  -0.711,   3.147,  -0.712,  -1.547,
#          1.132,   0.756,   0.308,   2.897,  -1.423,   2.177,   3.094,
#          1.89 ,   0.8  ,  -3.036,   0.792,   2.964,   0.72 ,  -1.005,
#          2.726,  -2.143, -11.419,  -5.095,   0.789,  -2.203,   0.461,
#         -1.814,   3.968,  -2.7  ,   0.232,   3.482,  -0.411,  -0.61 ,
#         -3.619,   3.19 ,  -4.804,   1.336,   2.075,  -2.445,   1.913,
#          1.505,   4.135,   3.384,   3.124,  -0.727,  -0.724,  -1.666,
#         -2.602,   0.199,  -0.95 ,   1.378,  -1.991,   2.096,   2.32 ,
#          0.089,  -5.721,   1.172,  -0.436,  -2.876,  -2.251,  -2.265,
#         -0.831,   1.3  ,  -1.207,  -1.534,   3.193,   3.264,   2.225,
#         -1.858,  -0.542,   3.624])

# %%
#nn model
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras import optimizers
shape = X_train.shape
# model = Sequential()
# model.add(Dense(10, input_shape = [shape[1],], activation = 'sigmoid'))
# model.add(Dense(20, activation = 'sigmoid'))
# model.add(Dense(10, activation = 'sigmoid'))
# model.add(Dense(1, activation = 'linear'))

# sgd = optimizers.SGD(lr=0.1, decay=0.01, momentum=0.9, nesterov=True)
# model.compile(loss='mean_squared_error', optimizer=sgd)

#history = model.fit(X_train,Y_tarin,epochs=100,batch_size = 4)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(10, kernel_initializer='normal',input_dim =shape[1], activation='tanh'))

# The Hidden Layers :
NN_model.add(Dense(10, kernel_initializer='normal',activation='tanh'))
# NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
# NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adagrad', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# history = NN_model.fit(X,Y,epochs=100,batch_size = 4, validation_data=[test,label])
history = NN_model.fit(X_train,Y_train,epochs=100,batch_size = 4, validation_split=0)
# Out:
# Train on 75 samples, validate on 19 samples
# Epoch 1/100
# 75/75 [==============================] - 1s 8ms/step - loss: 1.9868 - mean_absolute_error: 1.9868 - val_loss: 1.9953 - val_mean_absolute_error: 1.9953
# Epoch 2/100
# 75/75 [==============================] - 0s 409us/step - loss: 1.8617 - mean_absolute_error: 1.8617 - val_loss: 1.8861 - val_mean_absolute_error: 1.8861
# Epoch 3/100
# 75/75 [==============================] - 0s 432us/step - loss: 1.6810 - mean_absolute_error: 1.6810 - val_loss: 1.8096 - val_mean_absolute_error: 1.8096
# Epoch 4/100
# 75/75 [==============================] - 0s 379us/step - loss: 1.5573 - mean_absolute_error: 1.5573 - val_loss: 1.7425 - val_mean_absolute_error: 1.7425
# Epoch 5/100
# 75/75 [==============================] - 0s 346us/step - loss: 1.4722 - mean_absolute_error: 1.4722 - val_loss: 1.6749 - val_mean_absolute_error: 1.6749
# Epoch 6/100
# 75/75 [==============================] - 0s 326us/step - loss: 1.4266 - mean_absolute_error: 1.4266 - val_loss: 1.6359 - val_mean_absolute_error: 1.6359
# Epoch 7/100
# 75/75 [==============================] - 0s 324us/step - loss: 1.4075 - mean_absolute_error: 1.4075 - val_loss: 1.6076 - val_mean_absolute_error: 1.6076
# Epoch 8/100
# 75/75 [==============================] - 0s 340us/step - loss: 1.3941 - mean_absolute_error: 1.3941 - val_loss: 1.5834 - val_mean_absolute_error: 1.5834
# Epoch 9/100
# 75/75 [==============================] - 0s 342us/step - loss: 1.3813 - mean_absolute_error: 1.3813 - val_loss: 1.5589 - val_mean_absolute_error: 1.5589
# Epoch 10/100
# 75/75 [==============================] - 0s 313us/step - loss: 1.3723 - mean_absolute_error: 1.3723 - val_loss: 1.5393 - val_mean_absolute_error: 1.5393
# Epoch 11/100
# 75/75 [==============================] - 0s 309us/step - loss: 1.3648 - mean_absolute_error: 1.3648 - val_loss: 1.5246 - val_mean_absolute_error: 1.5246
# Epoch 12/100
# 75/75 [==============================] - 0s 332us/step - loss: 1.3578 - mean_absolute_error: 1.3578 - val_loss: 1.5089 - val_mean_absolute_error: 1.5089
# Epoch 13/100
# 75/75 [==============================] - 0s 318us/step - loss: 1.3507 - mean_absolute_error: 1.3507 - val_loss: 1.4943 - val_mean_absolute_error: 1.4943
# Epoch 14/100
# 75/75 [==============================] - 0s 308us/step - loss: 1.3468 - mean_absolute_error: 1.3468 - val_loss: 1.4796 - val_mean_absolute_error: 1.4796
# Epoch 15/100
# 75/75 [==============================] - 0s 307us/step - loss: 1.3432 - mean_absolute_error: 1.3432 - val_loss: 1.4687 - val_mean_absolute_error: 1.4687
# Epoch 16/100
# 75/75 [==============================] - 0s 312us/step - loss: 1.3390 - mean_absolute_error: 1.3390 - val_loss: 1.4598 - val_mean_absolute_error: 1.4598
# Epoch 17/100
# 75/75 [==============================] - 0s 313us/step - loss: 1.3346 - mean_absolute_error: 1.3346 - val_loss: 1.4500 - val_mean_absolute_error: 1.4500
# Epoch 18/100
# 75/75 [==============================] - 0s 309us/step - loss: 1.3338 - mean_absolute_error: 1.3338 - val_loss: 1.4424 - val_mean_absolute_error: 1.4424
# Epoch 19/100
# 75/75 [==============================] - 0s 317us/step - loss: 1.3317 - mean_absolute_error: 1.3317 - val_loss: 1.4344 - val_mean_absolute_error: 1.4344
# Epoch 20/100
# 75/75 [==============================] - 0s 312us/step - loss: 1.3275 - mean_absolute_error: 1.3275 - val_loss: 1.4244 - val_mean_absolute_error: 1.4244
# Epoch 21/100
# 75/75 [==============================] - 0s 313us/step - loss: 1.3251 - mean_absolute_error: 1.3251 - val_loss: 1.4154 - val_mean_absolute_error: 1.4154
# Epoch 22/100
# 75/75 [==============================] - 0s 312us/step - loss: 1.3225 - mean_absolute_error: 1.3225 - val_loss: 1.4063 - val_mean_absolute_error: 1.4063
# Epoch 23/100
# 75/75 [==============================] - 0s 323us/step - loss: 1.3198 - mean_absolute_error: 1.3198 - val_loss: 1.3966 - val_mean_absolute_error: 1.3966
# Epoch 24/100
# 75/75 [==============================] - 0s 315us/step - loss: 1.3177 - mean_absolute_error: 1.3177 - val_loss: 1.3870 - val_mean_absolute_error: 1.3870
# Epoch 25/100
# 75/75 [==============================] - 0s 307us/step - loss: 1.3142 - mean_absolute_error: 1.3142 - val_loss: 1.3775 - val_mean_absolute_error: 1.3775
# Epoch 26/100
# 75/75 [==============================] - 0s 327us/step - loss: 1.3114 - mean_absolute_error: 1.3114 - val_loss: 1.3708 - val_mean_absolute_error: 1.3708
# Epoch 27/100
# 75/75 [==============================] - 0s 329us/step - loss: 1.3101 - mean_absolute_error: 1.3101 - val_loss: 1.3614 - val_mean_absolute_error: 1.3614
# Epoch 28/100
# 75/75 [==============================] - 0s 342us/step - loss: 1.3063 - mean_absolute_error: 1.3063 - val_loss: 1.3518 - val_mean_absolute_error: 1.3518
# Epoch 29/100
# 75/75 [==============================] - 0s 345us/step - loss: 1.3050 - mean_absolute_error: 1.3050 - val_loss: 1.3434 - val_mean_absolute_error: 1.3434
# Epoch 30/100
# 75/75 [==============================] - 0s 332us/step - loss: 1.3029 - mean_absolute_error: 1.3029 - val_loss: 1.3385 - val_mean_absolute_error: 1.3385
# Epoch 31/100
# 75/75 [==============================] - 0s 347us/step - loss: 1.3014 - mean_absolute_error: 1.3014 - val_loss: 1.3300 - val_mean_absolute_error: 1.3300
# Epoch 32/100
# 75/75 [==============================] - 0s 357us/step - loss: 1.3004 - mean_absolute_error: 1.3004 - val_loss: 1.3210 - val_mean_absolute_error: 1.3210
# Epoch 33/100
# 75/75 [==============================] - 0s 351us/step - loss: 1.2985 - mean_absolute_error: 1.2985 - val_loss: 1.3135 - val_mean_absolute_error: 1.3135
# Epoch 34/100
# 75/75 [==============================] - 0s 346us/step - loss: 1.2969 - mean_absolute_error: 1.2969 - val_loss: 1.3073 - val_mean_absolute_error: 1.3073
# Epoch 35/100
# 75/75 [==============================] - 0s 322us/step - loss: 1.2964 - mean_absolute_error: 1.2964 - val_loss: 1.3002 - val_mean_absolute_error: 1.3002
# Epoch 36/100
# 75/75 [==============================] - 0s 347us/step - loss: 1.2941 - mean_absolute_error: 1.2941 - val_loss: 1.2936 - val_mean_absolute_error: 1.2936
# Epoch 37/100
# 75/75 [==============================] - 0s 335us/step - loss: 1.2918 - mean_absolute_error: 1.2918 - val_loss: 1.2898 - val_mean_absolute_error: 1.2898
# Epoch 38/100
# 75/75 [==============================] - 0s 333us/step - loss: 1.2911 - mean_absolute_error: 1.2911 - val_loss: 1.2816 - val_mean_absolute_error: 1.2816
# Epoch 39/100
# 75/75 [==============================] - 0s 318us/step - loss: 1.2905 - mean_absolute_error: 1.2905 - val_loss: 1.2762 - val_mean_absolute_error: 1.2762
# Epoch 40/100
# 75/75 [==============================] - 0s 331us/step - loss: 1.2904 - mean_absolute_error: 1.2904 - val_loss: 1.2717 - val_mean_absolute_error: 1.2717
# Epoch 41/100
# 75/75 [==============================] - 0s 318us/step - loss: 1.2878 - mean_absolute_error: 1.2878 - val_loss: 1.2680 - val_mean_absolute_error: 1.2680
# Epoch 42/100
# 75/75 [==============================] - 0s 344us/step - loss: 1.2860 - mean_absolute_error: 1.2860 - val_loss: 1.2615 - val_mean_absolute_error: 1.2615
# Epoch 43/100
# 75/75 [==============================] - 0s 327us/step - loss: 1.2850 - mean_absolute_error: 1.2850 - val_loss: 1.2539 - val_mean_absolute_error: 1.2539
# Epoch 44/100
# 75/75 [==============================] - 0s 350us/step - loss: 1.2846 - mean_absolute_error: 1.2846 - val_loss: 1.2491 - val_mean_absolute_error: 1.2491
# Epoch 45/100
# 75/75 [==============================] - 0s 325us/step - loss: 1.2831 - mean_absolute_error: 1.2831 - val_loss: 1.2437 - val_mean_absolute_error: 1.2437
# Epoch 46/100
# 75/75 [==============================] - 0s 343us/step - loss: 1.2825 - mean_absolute_error: 1.2825 - val_loss: 1.2384 - val_mean_absolute_error: 1.2384
# Epoch 47/100
# 75/75 [==============================] - 0s 339us/step - loss: 1.2812 - mean_absolute_error: 1.2812 - val_loss: 1.2336 - val_mean_absolute_error: 1.2336
# Epoch 48/100
# 75/75 [==============================] - 0s 331us/step - loss: 1.2802 - mean_absolute_error: 1.2802 - val_loss: 1.2287 - val_mean_absolute_error: 1.2287
# Epoch 49/100
# 75/75 [==============================] - 0s 337us/step - loss: 1.2796 - mean_absolute_error: 1.2796 - val_loss: 1.2245 - val_mean_absolute_error: 1.2245
# Epoch 50/100
# 75/75 [==============================] - 0s 350us/step - loss: 1.2782 - mean_absolute_error: 1.2782 - val_loss: 1.2196 - val_mean_absolute_error: 1.2196
# Epoch 51/100
# 75/75 [==============================] - 0s 339us/step - loss: 1.2784 - mean_absolute_error: 1.2784 - val_loss: 1.2152 - val_mean_absolute_error: 1.2152
# Epoch 52/100
# 75/75 [==============================] - 0s 301us/step - loss: 1.2768 - mean_absolute_error: 1.2768 - val_loss: 1.2107 - val_mean_absolute_error: 1.2107
# Epoch 53/100
# 75/75 [==============================] - 0s 288us/step - loss: 1.2751 - mean_absolute_error: 1.2751 - val_loss: 1.2070 - val_mean_absolute_error: 1.2070
# Epoch 54/100
# 75/75 [==============================] - 0s 289us/step - loss: 1.2751 - mean_absolute_error: 1.2751 - val_loss: 1.2026 - val_mean_absolute_error: 1.2026
# Epoch 55/100
# 75/75 [==============================] - 0s 289us/step - loss: 1.2732 - mean_absolute_error: 1.2732 - val_loss: 1.1981 - val_mean_absolute_error: 1.1981
# Epoch 56/100
# 75/75 [==============================] - 0s 286us/step - loss: 1.2724 - mean_absolute_error: 1.2724 - val_loss: 1.1928 - val_mean_absolute_error: 1.1928
# Epoch 57/100
# 75/75 [==============================] - 0s 301us/step - loss: 1.2715 - mean_absolute_error: 1.2715 - val_loss: 1.1883 - val_mean_absolute_error: 1.1883
# Epoch 58/100
# 75/75 [==============================] - 0s 297us/step - loss: 1.2701 - mean_absolute_error: 1.2701 - val_loss: 1.1830 - val_mean_absolute_error: 1.1830
# Epoch 59/100
# 75/75 [==============================] - 0s 292us/step - loss: 1.2701 - mean_absolute_error: 1.2701 - val_loss: 1.1786 - val_mean_absolute_error: 1.1786
# Epoch 60/100
# 75/75 [==============================] - 0s 313us/step - loss: 1.2678 - mean_absolute_error: 1.2678 - val_loss: 1.1721 - val_mean_absolute_error: 1.1721
# Epoch 61/100
# 75/75 [==============================] - 0s 359us/step - loss: 1.2675 - mean_absolute_error: 1.2675 - val_loss: 1.1684 - val_mean_absolute_error: 1.1684
# Epoch 62/100
# 75/75 [==============================] - 0s 314us/step - loss: 1.2660 - mean_absolute_error: 1.2660 - val_loss: 1.1655 - val_mean_absolute_error: 1.1655
# Epoch 63/100
# 75/75 [==============================] - 0s 308us/step - loss: 1.2665 - mean_absolute_error: 1.2665 - val_loss: 1.1621 - val_mean_absolute_error: 1.1621
# Epoch 64/100
# 75/75 [==============================] - 0s 310us/step - loss: 1.2654 - mean_absolute_error: 1.2654 - val_loss: 1.1584 - val_mean_absolute_error: 1.1584
# Epoch 65/100
# 75/75 [==============================] - 0s 324us/step - loss: 1.2660 - mean_absolute_error: 1.2660 - val_loss: 1.1554 - val_mean_absolute_error: 1.1554
# Epoch 66/100
# 75/75 [==============================] - 0s 314us/step - loss: 1.2644 - mean_absolute_error: 1.2644 - val_loss: 1.1528 - val_mean_absolute_error: 1.1528
# Epoch 67/100
# 75/75 [==============================] - 0s 293us/step - loss: 1.2645 - mean_absolute_error: 1.2645 - val_loss: 1.1505 - val_mean_absolute_error: 1.1505
# Epoch 68/100
# 75/75 [==============================] - 0s 295us/step - loss: 1.2635 - mean_absolute_error: 1.2635 - val_loss: 1.1459 - val_mean_absolute_error: 1.1459
# Epoch 69/100
# 75/75 [==============================] - 0s 294us/step - loss: 1.2633 - mean_absolute_error: 1.2633 - val_loss: 1.1411 - val_mean_absolute_error: 1.1411
# Epoch 70/100
# 75/75 [==============================] - 0s 288us/step - loss: 1.2624 - mean_absolute_error: 1.2624 - val_loss: 1.1389 - val_mean_absolute_error: 1.1389
# Epoch 71/100
# 75/75 [==============================] - 0s 285us/step - loss: 1.2628 - mean_absolute_error: 1.2628 - val_loss: 1.1368 - val_mean_absolute_error: 1.1368
# Epoch 72/100
# 75/75 [==============================] - 0s 290us/step - loss: 1.2617 - mean_absolute_error: 1.2617 - val_loss: 1.1324 - val_mean_absolute_error: 1.1324
# Epoch 73/100
# 75/75 [==============================] - 0s 294us/step - loss: 1.2613 - mean_absolute_error: 1.2613 - val_loss: 1.1301 - val_mean_absolute_error: 1.1301
# Epoch 74/100
# 75/75 [==============================] - 0s 300us/step - loss: 1.2612 - mean_absolute_error: 1.2612 - val_loss: 1.1282 - val_mean_absolute_error: 1.1282
# Epoch 75/100
# 75/75 [==============================] - 0s 340us/step - loss: 1.2600 - mean_absolute_error: 1.2600 - val_loss: 1.1258 - val_mean_absolute_error: 1.1258
# Epoch 76/100
# 75/75 [==============================] - 0s 320us/step - loss: 1.2599 - mean_absolute_error: 1.2599 - val_loss: 1.1256 - val_mean_absolute_error: 1.1256
# Epoch 77/100
# 75/75 [==============================] - 0s 317us/step - loss: 1.2598 - mean_absolute_error: 1.2598 - val_loss: 1.1216 - val_mean_absolute_error: 1.1216
# Epoch 78/100
# 75/75 [==============================] - 0s 334us/step - loss: 1.2592 - mean_absolute_error: 1.2592 - val_loss: 1.1193 - val_mean_absolute_error: 1.1193
# Epoch 79/100
# 75/75 [==============================] - 0s 316us/step - loss: 1.2591 - mean_absolute_error: 1.2591 - val_loss: 1.1190 - val_mean_absolute_error: 1.1190
# Epoch 80/100
# 75/75 [==============================] - 0s 330us/step - loss: 1.2591 - mean_absolute_error: 1.2591 - val_loss: 1.1189 - val_mean_absolute_error: 1.1189
# Epoch 81/100
# 75/75 [==============================] - 0s 321us/step - loss: 1.2587 - mean_absolute_error: 1.2587 - val_loss: 1.1173 - val_mean_absolute_error: 1.1173
# Epoch 82/100
# 75/75 [==============================] - 0s 331us/step - loss: 1.2582 - mean_absolute_error: 1.2582 - val_loss: 1.1147 - val_mean_absolute_error: 1.1147
# Epoch 83/100
# 75/75 [==============================] - 0s 346us/step - loss: 1.2577 - mean_absolute_error: 1.2577 - val_loss: 1.1149 - val_mean_absolute_error: 1.1149
# Epoch 84/100
# 75/75 [==============================] - 0s 336us/step - loss: 1.2582 - mean_absolute_error: 1.2582 - val_loss: 1.1130 - val_mean_absolute_error: 1.1130
# Epoch 85/100
# 75/75 [==============================] - 0s 340us/step - loss: 1.2579 - mean_absolute_error: 1.2579 - val_loss: 1.1108 - val_mean_absolute_error: 1.1108
# Epoch 86/100
# 75/75 [==============================] - 0s 315us/step - loss: 1.2572 - mean_absolute_error: 1.2572 - val_loss: 1.1090 - val_mean_absolute_error: 1.1090
# Epoch 87/100
# 75/75 [==============================] - 0s 342us/step - loss: 1.2573 - mean_absolute_error: 1.2573 - val_loss: 1.1088 - val_mean_absolute_error: 1.1088
# Epoch 88/100
# 75/75 [==============================] - 0s 323us/step - loss: 1.2564 - mean_absolute_error: 1.2564 - val_loss: 1.1073 - val_mean_absolute_error: 1.1073
# Epoch 89/100
# 75/75 [==============================] - 0s 351us/step - loss: 1.2564 - mean_absolute_error: 1.2564 - val_loss: 1.1069 - val_mean_absolute_error: 1.1069
# Epoch 90/100
# 75/75 [==============================] - 0s 349us/step - loss: 1.2562 - mean_absolute_error: 1.2562 - val_loss: 1.1063 - val_mean_absolute_error: 1.1063
# Epoch 91/100
# 75/75 [==============================] - 0s 322us/step - loss: 1.2561 - mean_absolute_error: 1.2561 - val_loss: 1.1045 - val_mean_absolute_error: 1.1045
# Epoch 92/100
# 75/75 [==============================] - 0s 313us/step - loss: 1.2554 - mean_absolute_error: 1.2554 - val_loss: 1.1038 - val_mean_absolute_error: 1.1038
# Epoch 93/100
# 75/75 [==============================] - 0s 347us/step - loss: 1.2550 - mean_absolute_error: 1.2550 - val_loss: 1.1033 - val_mean_absolute_error: 1.1033
# Epoch 94/100
# 75/75 [==============================] - 0s 364us/step - loss: 1.2553 - mean_absolute_error: 1.2553 - val_loss: 1.0997 - val_mean_absolute_error: 1.0997
# Epoch 95/100
# 75/75 [==============================] - 0s 320us/step - loss: 1.2546 - mean_absolute_error: 1.2546 - val_loss: 1.0981 - val_mean_absolute_error: 1.0981
# Epoch 96/100
# 75/75 [==============================] - 0s 355us/step - loss: 1.2544 - mean_absolute_error: 1.2544 - val_loss: 1.0961 - val_mean_absolute_error: 1.0961
# Epoch 97/100
# 75/75 [==============================] - 0s 349us/step - loss: 1.2544 - mean_absolute_error: 1.2544 - val_loss: 1.0949 - val_mean_absolute_error: 1.0949
# Epoch 98/100
# 75/75 [==============================] - 0s 376us/step - loss: 1.2545 - mean_absolute_error: 1.2545 - val_loss: 1.0951 - val_mean_absolute_error: 1.0951
# Epoch 99/100
# 75/75 [==============================] - 0s 351us/step - loss: 1.2539 - mean_absolute_error: 1.2539 - val_loss: 1.0948 - val_mean_absolute_error: 1.0948
# Epoch 100/100
# 75/75 [==============================] - 0s 355us/step - loss: 1.2537 - mean_absolute_error: 1.2537 - val_loss: 1.0955 - val_mean_absolute_error: 1.0955

# %%
import matplotlib.pyplot as plt
Y_pred = NN_model.predict(X_test)
plt.plot(history.history['loss'],label = 'loss')
plt.plot(history.history['val_loss'],label = 'val_loss')
plt.legend()
print(mean_squared_error(Y_pred, Y_test))
# Out:
# 1.9435551047467066

# %%
data_test = pd.read_csv("E_Vo_dopedPerovskites_interpolated.csv")
df_test= pd.DataFrame(data_test)
df_test

# %%
df_test = df_test[['Radius A [ang]', 'A-Density','A-AtomicNumber','A-SpecificHeat','B-AtomicMass',
                   'Vacancy energy [eV/O atom]']]

# %%
df_test.head(15)

# %%
test = df_test.values[:, 0:-1]
label = df_test.values[:,-1]

# %%
scaler = StandardScaler()
test = scaler.fit_transform(test)

# %%
test_pred = NN_model.predict(test)

# %%
mean_squared_error(label,test_pred)

# %%
test_pred

# %%
import matplotlib.pyplot as plt
Y_pred = NN_model.predict(test)
plt.plot(history.history['loss'],label = 'loss')
plt.plot(history.history['val_loss'],label = 'val_loss')
plt.legend()
print(mean_squared_error(Y_pred, label))
