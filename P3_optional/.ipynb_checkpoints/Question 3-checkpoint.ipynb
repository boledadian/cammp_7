# %%
import pandas as pd
data = pd.read_csv("2017 high throughoutDFT calculations of formation energy stability and oxygen vacancy formation energy of ABO3 prerovskites.csv")
df= pd.DataFrame(data)

# %%
df
# Out:
#      Chemical formula   A   B  In literature          Valence A  \
# 0               Ac2O3  Ac  Ac          False  element not in BV
# 1              AcAgO3  Ac  Ag          False  element not in BV
# 2              AcAlO3  Ac  Al          False  element not in BV
# 3              AcAsO3  Ac  As          False  element not in BV
# 4              AcAuO3  Ac  Au          False  element not in BV
# 5               AcBO3  Ac   B          False  element not in BV
# 6              AcBaO3  Ac  Ba          False  element not in BV
# 7              AcBeO3  Ac  Be          False  element not in BV
# 8              AcBiO3  Ac  Bi          False  element not in BV
# 9              AcCaO3  Ac  Ca          False  element not in BV
# 10             AcCdO3  Ac  Cd          False  element not in BV
# 11             AcCeO3  Ac  Ce          False  element not in BV
# 12             AcCoO3  Ac  Co          False  element not in BV
# 13             AcCrO3  Ac  Cr          False  element not in BV
# ...

# %%
df_temp1= [df['B'] == 'Fe']
df_temp2= [df['B'] == 'Co']

# %%
df_temp = df[df['B'].isin(['Fe','Co'])]

# %%
len(df_temp)
# Out:
# 146

# %%
df_temp.keys()
# Out:
# Index(['Chemical formula', 'A', 'B', 'In literature', 'Valence A', 'Valence B',
#        'Radius A [ang]', 'Radius B [ang]', 'Lowest distortion',
#        'Formation energy [eV/atom]', 'Stability [eV/atom]',
#        'Magnetic moment [mu_B]', 'Volume per atom [A^3/atom]', 'Band gap [eV]',
#        'a [ang]', 'b [ang]', 'c [ang]', 'alpha [deg]', 'beta [deg]',
#        'gamma [deg]', 'Vacancy energy [eV/O atom]'],
#       dtype='object')

# %%
df_temp = df_temp.drop(['alpha [deg]','beta [deg]','gamma [deg]','In literature'], axis = 1)

# %%
df_temp
# Out:
#      Chemical formula   A   B          Valence A          Valence B  \
# 12             AcCoO3  Ac  Co  element not in BV  element not in BV
# 19             AcFeO3  Ac  Fe  element not in BV  element not in BV
# 85             AgCoO3  Ag  Co       not balanced       not balanced
# 92             AgFeO3  Ag  Fe       not balanced       not balanced
# 158            AlCoO3  Al  Co                  3                  3
# 165            AlFeO3  Al  Fe                  3                  3
# 231            AsCoO3  As  Co                  3                  3
# 238            AsFeO3  As  Fe                  3                  3
# 304            AuCoO3  Au  Co  element not in BV  element not in BV
# 311            AuFeO3  Au  Fe  element not in BV  element not in BV
# 377             BCoO3   B  Co                  2                  4
# 384             BFeO3   B  Fe                  1                  5
# 450            BaCoO3  Ba  Co                  2                  4
# ...

# %%
df_temp.keys()
# Out:
# Index(['Chemical formula', 'A', 'B', 'Valence A', 'Valence B',
#        'Radius A [ang]', 'Radius B [ang]', 'Lowest distortion',
#        'Formation energy [eV/atom]', 'Stability [eV/atom]',
#        'Magnetic moment [mu_B]', 'Volume per atom [A^3/atom]', 'Band gap [eV]',
#        'a [ang]', 'b [ang]', 'c [ang]', 'Vacancy energy [eV/O atom]'],
#       dtype='object')

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
