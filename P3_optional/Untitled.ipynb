# %%
import pandas as pd
data = pd.read_csv("2017 high throughoutDFT calculations of formation energy stability and oxygen vacancy formation energy of ABO3 prerovskites.csv")
df= pd.DataFrame(data)

# %%
df
# Out:
#      Chemical formula   A   B  In literature          Valence A  \
# 0               Ac2O3  Ac  Ac          False  element not in BV
# 1              AcAgO3  Ac  Ag          False  element not in BV
# 2              AcAlO3  Ac  Al          False  element not in BV
# 3              AcAsO3  Ac  As          False  element not in BV
# 4              AcAuO3  Ac  Au          False  element not in BV
# 5               AcBO3  Ac   B          False  element not in BV
# 6              AcBaO3  Ac  Ba          False  element not in BV
# 7              AcBeO3  Ac  Be          False  element not in BV
# 8              AcBiO3  Ac  Bi          False  element not in BV
# 9              AcCaO3  Ac  Ca          False  element not in BV
# 10             AcCdO3  Ac  Cd          False  element not in BV
# 11             AcCeO3  Ac  Ce          False  element not in BV
# 12             AcCoO3  Ac  Co          False  element not in BV
# 13             AcCrO3  Ac  Cr          False  element not in BV
# 14             AcCsO3  Ac  Cs          False  element not in BV
# 15             AcCuO3  Ac  Cu          False  element not in BV
# 16             AcDyO3  Ac  Dy          False  element not in BV
# 17             AcErO3  Ac  Er          False  element not in BV
# 18             AcEuO3  Ac  Eu          False  element not in BV
# 19             AcFeO3  Ac  Fe          False  element not in BV
# 20             AcGaO3  Ac  Ga          False  element not in BV
# 21             AcGdO3  Ac  Gd          False  element not in BV
# 22             AcGeO3  Ac  Ge          False  element not in BV
# 23             AcHfO3  Ac  Hf          False  element not in BV
# 24             AcHgO3  Ac  Hg          False  element not in BV
# 25             AcHoO3  Ac  Ho          False  element not in BV
# 26             AcInO3  Ac  In          False  element not in BV
# 27             AcIrO3  Ac  Ir          False  element not in BV
# 28              AcKO3  Ac   K          False  element not in BV
# 29             AcLaO3  Ac  La          False  element not in BV
# ...               ...  ..  ..            ...                ...
# 5299           ZrPdO3  Zr  Pd          False       not balanced
# 5300           ZrPmO3  Zr  Pm          False  element not in BV
# 5301           ZrPrO3  Zr  Pr          False       not balanced
# 5302           ZrPtO3  Zr  Pt          False  element not in BV
# 5303           ZrPuO3  Zr  Pu          False  element not in BV
# 5304           ZrRbO3  Zr  Rb          False       not balanced
# 5305           ZrReO3  Zr  Re          False                  1
# 5306           ZrRhO3  Zr  Rh          False                  3
# 5307           ZrRuO3  Zr  Ru          False                  1
# 5308           ZrSbO3  Zr  Sb          False                  1
# 5309           ZrScO3  Zr  Sc          False       not balanced
# 5310           ZrSiO3  Zr  Si          False                  2
# 5311           ZrSmO3  Zr  Sm          False       not balanced
# 5312           ZrSnO3  Zr  Sn          False       not balanced
# 5313           ZrSrO3  Zr  Sr          False       not balanced
# 5314           ZrTaO3  Zr  Ta          False                  1
# 5315           ZrTbO3  Zr  Tb          False       not balanced
# 5316           ZrTcO3  Zr  Tc          False  element not in BV
# 5317           ZrTeO3  Zr  Te          False       not balanced
# 5318           ZrThO3  Zr  Th          False       not balanced
# 5319           ZrTiO3  Zr  Ti          False                  2
# 5320           ZrTlO3  Zr  Tl          False       not balanced
# 5321           ZrTmO3  Zr  Tm          False       not balanced
# 5322            ZrUO3  Zr   U          False                  1
# 5323            ZrVO3  Zr   V          False                  1
# 5324            ZrWO3  Zr   W          False                  1
# 5325            ZrYO3  Zr   Y          False       not balanced
# 5326           ZrYbO3  Zr  Yb          False       not balanced
# 5327           ZrZnO3  Zr  Zn          False       not balanced
# 5328            Zr2O3  Zr  Zr          False       not balanced
#
#               Valence B  Radius A [ang]  Radius B [ang] Lowest distortion  \
# 0     element not in BV            1.12            1.12             cubic
# 1     element not in BV            1.12            0.95      orthorhombic
# 2     element not in BV            1.12            0.54             cubic
# 3     element not in BV            1.12            0.52      orthorhombic
# 4     element not in BV            1.12            0.93      orthorhombic
# 5     element not in BV            1.12            0.27             cubic
# 6     element not in BV            1.12            1.35      orthorhombic
# 7     element not in BV            1.12            0.45             cubic
# 8     element not in BV            1.12            0.90      orthorhombic
# 9     element not in BV            1.12            1.00      orthorhombic
# 10    element not in BV            1.12            0.95      orthorhombic
# 11    element not in BV            1.12            0.94             cubic
# 12    element not in BV            1.12            0.63      rhombohedral
# 13    element not in BV            1.12            0.58      orthorhombic
# 14    element not in BV            1.12            1.67        tetragonal
# 15    element not in BV            1.12            0.68      orthorhombic
# 16    element not in BV            1.12            0.99      orthorhombic
# 17    element not in BV            1.12            0.89      orthorhombic
# 18    element not in BV            1.12            1.06      orthorhombic
# 19    element not in BV            1.12            0.67      orthorhombic
# 20    element not in BV            1.12            0.62      orthorhombic
# 21    element not in BV            1.12            0.94      orthorhombic
# 22    element not in BV            1.12            0.63      orthorhombic
# 23    element not in BV            1.12            0.71      orthorhombic
# 24    element not in BV            1.12            1.11      orthorhombic
# 25    element not in BV            1.12            0.90      orthorhombic
# 26    element not in BV            1.12            0.80      orthorhombic
# 27    element not in BV            1.12            0.63      orthorhombic
# 28    element not in BV            1.12            1.38      orthorhombic
# 29    element not in BV            1.12            1.03             cubic
# ...                 ...             ...             ...               ...
# 5299       not balanced            0.89            0.75             cubic
# 5300  element not in BV            0.89            0.97             cubic
# 5301       not balanced            0.89            0.92      orthorhombic
# 5302  element not in BV            0.89            0.67             cubic
# 5303  element not in BV            0.89            0.83             cubic
# 5304       not balanced            0.89            1.52      orthorhombic
# 5305                  5            0.89            0.58             cubic
# 5306                  3            0.89            0.67             cubic
# 5307                  5            0.89            0.57             cubic
# 5308                  5            0.89            0.60             cubic
# 5309       not balanced            0.89            0.75             cubic
# 5310                  4            0.89            0.40             cubic
# 5311       not balanced            0.89            0.96             cubic
# 5312       not balanced            0.89            0.69      orthorhombic
# 5313       not balanced            0.89            1.18      orthorhombic
# 5314                  5            0.89            0.64             cubic
# 5315       not balanced            0.89            0.84             cubic
# 5316  element not in BV            0.89            0.60             cubic
# 5317       not balanced            0.89            0.77             cubic
# 5318       not balanced            0.89            0.94             cubic
# 5319                  4            0.89            0.61             cubic
# 5320       not balanced            0.89            1.20      orthorhombic
# 5321       not balanced            0.89            0.96             cubic
# 5322                  5            0.89            0.76      orthorhombic
# 5323                  5            0.89            0.54             cubic
# 5324                  5            0.89            0.62             cubic
# 5325       not balanced            0.89            0.90             cubic
# 5326       not balanced            0.89            0.95      orthorhombic
# 5327       not balanced            0.89            0.74             cubic
# 5328       not balanced            0.89            0.72             cubic
#
#      Formation energy [eV/atom]  ... Magnetic moment [mu_B]  \
# 0                        -2.732  ...                      0
# 1                        -1.957  ...                      0
# 2                        -3.532  ...                      0
# 3                        -2.398  ...                      0
# 4                        -2.006  ...                      0
# 5                        -2.316  ...                      0
# 6                        -2.741  ...                    0.2
# 7                        -2.715  ...                  0.183
# 8                          -2.5  ...                      0
# 9                        -2.964  ...                    0.2
# 10                       -2.224  ...                      0
# 11                       -2.864  ...                      0
# 12                       -2.426  ...                  0.592
# 13                       -3.138  ...                    0.6
# 14                       -1.602  ...                  0.004
# 15                       -2.241  ...                      0
# 16                       -3.712  ...                      0
# 17                       -3.748  ...                      0
# 18                        -3.04  ...                    0.2
# 19                       -2.731  ...                      1
# 20                       -2.914  ...                      0
# 21                        -3.67  ...                      0
# 22                       -2.547  ...                      0
# 23                       -3.414  ...                      0
# 24                       -1.951  ...                      0
# 25                       -3.731  ...                      0
# 26                       -2.748  ...                      0
# 27                       -2.194  ...                      0
# 28                       -1.973  ...                    0.4
# 29                       -2.983  ...                      0
# ...                         ...  ...                    ...
# 5299                     -1.022  ...                  0.011
# 5300                     -1.822  ...                    0.2
# 5301                      -3.14  ...                      0
# 5302                      -0.83  ...                  0.087
# 5303                     -2.051  ...                    1.2
# 5304                     -2.464  ...                    0.2
# 5305                     -1.308  ...                  0.209
# 5306                     -1.202  ...                  0.001
# 5307                     -1.281  ...                      0
# 5308                     -1.109  ...                  0.389
# 5309                     -2.585  ...                   0.14
# 5310                     -2.058  ...                  0.247
# 5311                     -1.879  ...                    0.2
# 5312                     -2.367  ...                      0
# 5313                     -3.229  ...                      0
# 5314                      -2.14  ...                  0.369
# 5315                     -1.963  ...                    0.2
# 5316                     -1.448  ...                  0.131
# 5317                      -0.83  ...                  0.382
# 5318                      -2.21  ...                  0.398
# 5319                     -2.535  ...                  0.178
# 5320                     -2.139  ...                  0.001
# 5321                     -2.315  ...                    0.2
# 5322                     -3.052  ...                  0.644
# 5323                     -2.208  ...                  0.543
# 5324                     -1.637  ...                  0.339
# 5325                     -2.126  ...                    0.2
# 5326                     -3.455  ...                      0
# 5327                      -1.63  ...                  0.001
# 5328                     -2.382  ...                  0.382
#
#      Volume per atom [A^3/atom] Band gap [eV] a [ang] b [ang] c [ang]  \
# 0                        20.836         0.332   4.705   4.705   4.705
# 1                        14.485             0   5.779   6.077   8.248
# 2                        11.487         4.307   3.858   3.858   3.858
# 3                        14.355             0    5.78   6.012   8.262
# 4                         15.19         0.745   5.899    6.75    7.63
# 5                        10.075         1.071   3.693   3.693   3.693
# 9             90         90          90                     -1.025
# 10            90         90          90                      0.264
# 11            90         90          90                      4.197
# 12          60.1       60.1        60.1                       3.33
# 13            90         90          90                      5.121
# 14            90         90          90                     -1.411
# 15            90         90          90                      1.596
# 16            90         90          90                       5.48
# 17            90         90          90                      5.682
# 18            90         90          90                     -0.381
# 19            90         90          90                      4.135
# 20            90         90          90                      5.294
# 21            90         90          90                      5.268
# 22            90         90          90                      3.511
# 23            90         90          90                      5.504
# 24            90         90          90                      0.336
# 25            90         90          90                      5.577
# 26            90         90          90                      3.988
# 27            90         90          90                      1.277
# 28            90         90          90                     -2.742
# 29            90         90          90                      4.187
# ...          ...        ...         ...                        ...
# 5299          90         90          90                     -1.494
# 5300          90         90          90                     -6.026
# 5301          90         90          90                     -8.028
# 5302          90         90          90                     -2.663
# 5303          90         90          90                       -4.9
# 5304          90         90          90                    -16.391
# 5305          90         90          90                     -0.946
# 5306          90         90          90                     -1.402
# 5307          90         90          90                     -1.215
# 5308          90         90          90                     -2.002
# 5309          90         90          90                     -0.591
# 5310          90         90          90                      2.891
# 5311          90         90          90                     -3.259
# 5312          90         90          90                      1.196
# 5313          90         90          90                    -10.761
# 5314          90         90          90                      2.082
# 5315          90         90          90                     -5.312
# 5316          90         90          90                     -0.429
# 5317          90         90          90                     -2.209
# 5318          90         90          90                      0.652
# 5319          90         90          90                      2.821
# 5320          90         90          90                     -2.018
# 5321          90         90          90                     -3.645
# 5322          90         90          90                      -1.56
# 5323          90         90          90                      2.395
# 5324          90         90          90                      0.191
# 5325          90         90          90                      -4.92
# 5326          90         90          90                     -6.177
# 5327          90         90          90                     -0.762
# 5328          90         90          90                      3.218
#
# [5329 rows x 21 columns]

# %%
df_temp1= [df['B'] == 'Fe']
df_temp2= [df['B'] == 'Co']

# %%
name = ['Fe','Co']
df_temp = df[df['B'].isin(name)]

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 12 to 5275
# Data columns (total 21 columns):
# Chemical formula              146 non-null object
# A                             146 non-null object
# B                             146 non-null object
# In literature                 146 non-null bool
# Valence A                     146 non-null object
# Valence B                     146 non-null object
# Radius A [ang]                146 non-null float64
# Radius B [ang]                146 non-null float64
# Lowest distortion             146 non-null object
# Formation energy [eV/atom]    146 non-null object
# Stability [eV/atom]           146 non-null object
# Magnetic moment [mu_B]        146 non-null object
# Volume per atom [A^3/atom]    146 non-null object
# Band gap [eV]                 146 non-null object
# a [ang]                       146 non-null object
# b [ang]                       146 non-null object
# c [ang]                       146 non-null object
# alpha [deg]                   146 non-null object
# beta [deg]                    146 non-null object
# gamma [deg]                   146 non-null object
# Vacancy energy [eV/O atom]    146 non-null object
# dtypes: bool(1), float64(2), object(18)
# memory usage: 24.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lt = LabelEncoder()
df_temp['Lowest distortion'] = lt.fit_transform(df_temp['Lowest distortion'])
df_temp['A'] = lt.fit_transform(df_temp['A'])
# Out:
# /Users/Heisen/anaconda3/envs/ML/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Heisen/anaconda3/envs/ML/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_temp = df_temp.drop(['Chemical formula','alpha [deg]','beta [deg]','gamma [deg]','In literature'], axis = 1)
df_temp.head()
# Out:
#      A   B          Valence A          Valence B  Radius A [ang]  \
# 12   0  Co  element not in BV  element not in BV            1.12
# 19   0  Fe  element not in BV  element not in BV            1.12
# 85   1  Co       not balanced       not balanced            1.28
# 92   1  Fe       not balanced       not balanced            1.28
# 158  2  Co                  3                  3            0.54
#
#      Radius B [ang]  Lowest distortion Formation energy [eV/atom]  \
# 12             0.63                  3                     -2.426
# 19             0.67                  2                     -2.731
# 85             0.63                  2                     -0.481
# 92             0.67                  2                     -0.817
# 158            0.61                  1                     -0.957
#
#     Stability [eV/atom] Magnetic moment [mu_B] Volume per atom [A^3/atom]  \
# 12                -0.01                  0.592                      11.94
# 19               -0.116                      1                     12.687
# 85                0.258                  0.005                     10.146
# 92                0.142                  0.851                      10.78
# 158               1.302                  0.005                      9.363
#
#     Band gap [eV] a [ang] b [ang] c [ang] Vacancy energy [eV/O atom]
# 12              0   5.522   5.522   5.522                       3.33
# 19          0.906    5.63   5.655    7.97                      4.135
# 85              0   5.208   5.302   7.348                          -
# 92              0   5.451   5.474   7.225                          -
# 158             0   3.604   3.604   3.604                     -1.991

# %%
import numpy as np
df_temp['Valence A'].replace(r'\s+', np.nan, regex=True, inplace=True)
df_temp['Valence B'].replace(r'\s+', np.nan, regex=True, inplace=True)
#weirdString = '-'#df_temp['Vacancy energy [eV/O atom]'][0:]
#df_temp['Vacancy energy [eV/O atom]'].replace(weirdString, np.nan, inplace=True)
df_temp = df_temp.replace(to_replace='-',value=np.nan)

# %%
# type(df_temp['Vacancy energy [eV/O atom]'][85])
# df_temp['Vacancy energy [eV/O atom]'][85]
#weirdString == df_temp['Vacancy energy [eV/O atom]'][85]

# %%
df_temp.head()
# Out:
#      A   B Valence A Valence B  Radius A [ang]  Radius B [ang]  \
# 12   0  Co       NaN       NaN            1.12            0.63
# 19   0  Fe       NaN       NaN            1.12            0.67
# 85   1  Co       NaN       NaN            1.28            0.63
# 92   1  Fe       NaN       NaN            1.28            0.67
# 158  2  Co         3         3            0.54            0.61
#
#      Lowest distortion Formation energy [eV/atom] Stability [eV/atom]  \
# 12                   3                     -2.426               -0.01
# 19                   2                     -2.731              -0.116
# 85                   2                     -0.481               0.258
# 92                   2                     -0.817               0.142
# 158                  1                     -0.957               1.302
#
#     Magnetic moment [mu_B] Volume per atom [A^3/atom] Band gap [eV] a [ang]  \
# 12                   0.592                      11.94             0   5.522
# 19                       1                     12.687         0.906    5.63
# 85                   0.005                     10.146             0   5.208
# 92                   0.851                      10.78             0   5.451
# 158                  0.005                      9.363             0   3.604
#
#     b [ang] c [ang] Vacancy energy [eV/O atom]
# 12    5.522   5.522                       3.33
# 19    5.655    7.97                      4.135
# 85    5.302   7.348                        NaN
# 92    5.474   7.225                        NaN
# 158   3.604   3.604                     -1.991

# %%
df_temp = df_temp.dropna()

# %%
df_temp.keys()
# Out:
# Index(['A', 'B', 'Valence A', 'Valence B', 'Radius A [ang]', 'Radius B [ang]',
#        'Lowest distortion', 'Formation energy [eV/atom]',
#        'Stability [eV/atom]', 'Magnetic moment [mu_B]',
#        'Volume per atom [A^3/atom]', 'Band gap [eV]', 'a [ang]', 'b [ang]',
#        'c [ang]', 'Vacancy energy [eV/O atom]'],
#       dtype='object')

# %%
df_temp = df_temp.drop(['B', 'A'], axis=1)
df_temp = df_temp.astype(float)
# Out:
# array([3., 3., 3., 3., 2., 1., 2., 2., 2., 2., 3., 3., 2., 2., 2., 2., 3.,
#        3., 3., 3., 2., 2., 2., 2., 3., 3., 2., 3., 2., 3., 3., 2., 2., 4.,
#        2., 2., 3., 3., 3., 3., 3., 3., 3., 1., 3., 3., 2., 2., 2., 3., 4.,
#        3., 3., 3., 3., 2., 2., 2., 3., 3., 5., 5., 3., 3., 2., 2., 3., 3.,
#        3., 2., 2., 3., 3., 2., 2., 2., 2., 2., 3., 3., 2., 2., 4., 4., 2.,
#        2., 3., 3., 3., 3., 3., 2., 3., 3., 3., 3., 2., 2., 3., 3.])

# %%
df_temp['Average_valence'] = 0.5*(df_temp['Valence A'].values+df_temp['Valence B'].values)
# Out:
#         Valence A   Valence B  Radius A [ang]  Radius B [ang]  \
# count  100.000000  100.000000      100.000000      100.000000
# mean     2.630000    3.370000        0.940500        0.608700
# std      0.691288    0.691288        0.305906        0.058546
# min      1.000000    1.000000        0.270000        0.530000
# 25%      2.000000    3.000000        0.720000        0.590000
# 50%      3.000000    3.000000        0.910000        0.610000
# 75%      3.000000    4.000000        1.140000        0.650000
# max      5.000000    5.000000        1.610000        0.780000
#
#        Lowest distortion  Formation energy [eV/atom]  Stability [eV/atom]  \
# count         100.000000                  100.000000           100.000000
# mean            1.520000                   -1.393090             0.590590
# std             0.643224                    0.899482             0.611442
# min             1.000000                   -2.947000            -0.123000
# 25%             1.000000                   -2.288000             0.021500
# 50%             1.000000                   -1.168500             0.562500
# 75%             2.000000                   -0.672500             0.980750
# max             4.000000                    0.418000             2.356000
#
#        Magnetic moment [mu_B]  Volume per atom [A^3/atom]  Band gap [eV]  \
# count              100.000000                  100.000000      100.00000
# mean                 0.699100                   10.664940        0.25014
# std                  0.509193                    0.860704        0.49812
# min                 -0.538000                    8.583000        0.00000
# 25%                  0.386250                    9.912750        0.00000
# 50%                  0.799000                   10.600000        0.00000
# 75%                  1.000000                   11.271250        0.00000
# max                  1.800000                   12.761000        1.86400
#
#           a [ang]     b [ang]     c [ang]  Vacancy energy [eV/O atom]  \
# count  100.000000  100.000000  100.000000                   100.00000
# mean     4.411350    4.496240    5.326370                     0.19527
# std      0.797104    0.893648    1.881446                     2.28254
# min      3.594000    3.594000    3.594000                    -5.72100
# 25%      3.684250    3.684250    3.685750                    -1.42875
# 50%      3.803000    3.803000    3.808500                     0.27000
# 75%      5.287500    5.492500    7.588000                     2.08025
# max      5.642000    5.933000    8.012000                     4.09400
#
#        Average_valence
# count            100.0
# mean               3.0
# std                0.0
# min                3.0
# 25%                3.0
# 50%                3.0
# 75%                3.0
# max                3.0

# %%
df_temp = df_temp.drop(['B', 'A'], axis=1)
df_temp = df_temp.astype(float)
df_temp = df_temp[['Radius A [ang]','Formation energy [eV/atom]','Stability [eV/atom]',
                   'Volume per atom [A^3/atom]','Magnetic moment [mu_B]','a [ang]',
                   'Vacancy energy [eV/O atom]']]
display(df_temp.head())
display(df_temp.describe())
# Out:
#      Radius A [ang]  Formation energy [eV/atom]  Stability [eV/atom]  \
# 158            0.54                      -0.957                1.302
# 165            0.54                      -1.125                1.332
# 231            0.58                      -0.584                0.820
# 238            0.58                      -0.747                0.805
# 377            0.27                       0.418                2.356
#
#      Volume per atom [A^3/atom]  Magnetic moment [mu_B]  a [ang]  \
# 158                       9.363                   0.005    3.604
# 165                      10.496                   0.853    3.744
# 231                       9.799                  -0.004    3.659
# 238                      10.955                   0.911    3.798
# 377                       9.511                  -0.538    3.623
#
#      Vacancy energy [eV/O atom]
# 158                      -1.991
# 165                      -2.445
# 231                       0.089
# 238                      -0.724
# 377                      -2.534
#        Radius A [ang]  Formation energy [eV/atom]  Stability [eV/atom]  \
# count      100.000000                  100.000000           100.000000
# mean         0.940500                   -1.393090             0.590590
# std          0.305906                    0.899482             0.611442
# min          0.270000                   -2.947000            -0.123000
# 25%          0.720000                   -2.288000             0.021500
# 50%          0.910000                   -1.168500             0.562500
# 75%          1.140000                   -0.672500             0.980750
# max          1.610000                    0.418000             2.356000
#
#        Volume per atom [A^3/atom]  Magnetic moment [mu_B]     a [ang]  \
# count                  100.000000              100.000000  100.000000
# mean                    10.664940                0.699100    4.411350
# std                      0.860704                0.509193    0.797104
# min                      8.583000               -0.538000    3.594000
# 25%                      9.912750                0.386250    3.684250
# 50%                     10.600000                0.799000    3.803000
# 75%                     11.271250                1.000000    5.287500
# max                     12.761000                1.800000    5.642000
#
#        Vacancy energy [eV/O atom]
# count                   100.00000
# mean                      0.19527
# std                       2.28254
# min                      -5.72100
# 25%                      -1.42875
# 50%                       0.27000
# 75%                       2.08025
# max                       4.09400

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X = df_temp.values[:, 0:-1]
Y = df_temp.values[:,-1]
print(Y)
# Out:
# [-1.991 -2.445  0.089 -0.724 -2.534 -3.619  0.663  1.185 -2.203 -1.666
#   2.897  2.587  0.72   1.132 -0.458  0.208  3.21   4.094 -2.8   -0.624
#  -1.758 -1.245 -1.005 -1.512  3.193  2.225  1.59   1.667 -1.547 -1.446
#   3.384  0.905  0.461  0.8   -1.207 -0.324  2.32   3.094  0.504 -5.721
#  -4.804  2.964  4.037 -0.831  1.89   2.726  0.07  -0.239  0.308 -0.95
#  -2.265  0.373 -0.263  3.124  3.83   0.756  0.789 -0.712 -1.858  3.968
#  -5.095 -4.592 -0.711 -2.494 -2.148 -2.602  2.075  1.172  1.089 -1.423
#  -1.814  2.931  3.624  0.792  0.687  1.378 -0.411 -4.452  2.511  3.264
#   1.913 -0.992  3.147  3.482  0.232 -0.463 -0.542 -0.727  2.096  2.865
#   2.177 -1.853 -2.7   -2.876  3.19   1.336 -1.336 -0.75   1.235  1.3  ]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
# model = LogisticRegression()
# rfe = RFE(model, 4)
# fit = rfe.fit(X, Y)

# %%
# print("Num Features: %s" % (fit.n_features_))
# print("Selected Features: %s" % (fit.support_))
# print("Feature Ranking: %s" % (fit.ranking_))

# %%
# import seaborn as sns
# #sns.p(df_temp[0:5])
# #pd.plotting.scatter_matrix(df_temp[11:14])
# sns.pairplot(df_temp.iloc[:,11:13], hue = df_temp.iloc[:, 14])

# %%
# fit.ranking_

# %%
# ind = np.where(fit.ranking_ == 1)
# idx = [item for item in ind[0]]

# %%
import seaborn as sns
sns.pairplot(df_temp)
import matplotlib.pyplot as plt
plt.savefig("pairplot_3features.png")

# %%
display(X.shape)
display(Y.shape)
# Out:
# (100, 6)
# (100,)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
scaler = StandardScaler()
#scaler  = MinMaxScaler()
X = scaler.fit_transform(X)
#Y = scaler.fit_transform(Y.reshape(-1,1))

# %%
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
clf = SVR(gamma=0.01, kernel='linear',C = 2000)
clf.fit(X_train, Y_train)
# Out:
# SVR(C=2000, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.01,
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
Y_pred = clf.predict(X_test)
from sklearn.metrics import mean_squared_error
print(mean_squared_error(Y_pred,Y_test))
plt.scatter(X_test[:, 2], Y_test)
plt.scatter(X_test[:, 2], Y_pred)
# Out:
# 1.9042328080000712

# %%
from sklearn.neighbors import KNeighborsRegressor
log = KNeighborsRegressor(n_neighbors=5)
log.fit(X_train, Y_train) 
Y_pred = log.predict(X_test)
print(mean_squared_error(Y_pred,Y_test))
plt.scatter(X_test[:, 0], Y_test)
plt.scatter(X_test[:, 0], Y_pred)
# Out:
# 2.5938864640000006

# %%
mean_squared_error
# Out:
# <function sklearn.metrics.regression.mean_squared_error(y_true, y_pred, sample_weight=None, multioutput='uniform_average')>

# %%
Y_train
# Out:
# array([ 0.756,  2.096,  1.59 ,  4.037, -1.423,  0.208, -4.804, -1.336,
#        -1.666,  3.624,  2.587, -0.239, -0.463, -1.547, -2.876, -3.619,
#         2.075, -2.602, -0.324,  3.21 , -0.95 , -1.207,  1.185,  1.336,
#         1.667, -0.624, -0.992,  2.225, -0.711,  1.132,  3.193, -0.724,
#         4.094,  0.504, -2.203,  2.511,  0.663, -2.148,  2.32 ,  2.865,
#         0.789,  1.3  ,  3.83 , -0.831, -2.265,  1.172,  0.07 ,  1.089,
#        -4.592, -0.75 ,  3.264,  2.964, -1.858,  0.308,  1.235, -0.712,
#         1.378,  0.461,  3.19 ,  3.968, -2.494,  0.232,  3.094, -1.446,
#        -2.445, -0.263, -1.245,  0.089, -1.512, -0.727, -1.853,  0.687,
#        -0.542,  3.147, -1.758, -5.095,  2.931, -0.458, -2.7  ,  0.373])

# %%
#nn model
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras import optimizers
shape = X_train.shape
model = Sequential()
model.add(Dense(10, input_shape = [shape[1],], activation = 'relu'))
model.add(Dense(20, input_shape = [shape[1],], activation = 'relu'))
model.add(Dense(10, input_shape = [shape[1],], activation = 'relu'))
model.add(Dense(1, activation = 'tanh'))

sgd = optimizers.SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error', optimizer=sgd)

#history = model.fit(X_train,Y_tarin,epochs=100,batch_size = 4)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/Heisen/anaconda3/envs/ML/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
history = model.fit(X_train,Y_train,epochs=100,batch_size = 4)
# Out:
# WARNING:tensorflow:From /Users/Heisen/anaconda3/envs/ML/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 80/80 [==============================] - 0s 6ms/step - loss: 5.4756
# Epoch 2/100
# 80/80 [==============================] - 0s 292us/step - loss: 5.3717
# Epoch 3/100
# 80/80 [==============================] - 0s 307us/step - loss: 5.3717
# Epoch 4/100
# 80/80 [==============================] - 0s 282us/step - loss: 5.3717
# Epoch 5/100
# 80/80 [==============================] - 0s 311us/step - loss: 5.3717
# Epoch 6/100
# 80/80 [==============================] - 0s 293us/step - loss: 5.3717
# Epoch 7/100
# 80/80 [==============================] - 0s 307us/step - loss: 5.3717
# Epoch 8/100
# 80/80 [==============================] - 0s 288us/step - loss: 5.3717
# Epoch 9/100
# 80/80 [==============================] - 0s 339us/step - loss: 5.3717
# Epoch 10/100
# 80/80 [==============================] - 0s 295us/step - loss: 5.3717
# Epoch 11/100
# 80/80 [==============================] - 0s 320us/step - loss: 5.3717
# Epoch 12/100
# 80/80 [==============================] - 0s 283us/step - loss: 5.3717
# Epoch 13/100
# 80/80 [==============================] - 0s 335us/step - loss: 5.3717
# Epoch 14/100
# 80/80 [==============================] - 0s 293us/step - loss: 5.3717
# Epoch 15/100
# 80/80 [==============================] - 0s 325us/step - loss: 5.3717
# Epoch 16/100
# 80/80 [==============================] - 0s 293us/step - loss: 5.3717
# Epoch 17/100
# 80/80 [==============================] - 0s 307us/step - loss: 5.3717
# Epoch 18/100
# 80/80 [==============================] - 0s 313us/step - loss: 5.3717
# Epoch 19/100
# 80/80 [==============================] - 0s 315us/step - loss: 5.3717
# Epoch 20/100
# 80/80 [==============================] - 0s 283us/step - loss: 5.3717
# Epoch 21/100
# 80/80 [==============================] - 0s 356us/step - loss: 5.3717
# Epoch 22/100
# 80/80 [==============================] - 0s 286us/step - loss: 5.3717
# Epoch 23/100
# 80/80 [==============================] - 0s 327us/step - loss: 5.3717
# Epoch 24/100
# 80/80 [==============================] - 0s 306us/step - loss: 5.3717
# Epoch 25/100
# 80/80 [==============================] - 0s 290us/step - loss: 5.3717
# Epoch 26/100
# 80/80 [==============================] - 0s 289us/step - loss: 5.3717
# Epoch 27/100
